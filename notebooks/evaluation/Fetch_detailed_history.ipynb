# %%
# %load_ext autoreload
# %autoreload 2
import os
import wandb
import pandas as pd
import glob
from dl_utils.utils import find_last_epoch_file, sort_tasks_by_size

# %%
api = wandb.Api()
entity, project = "yig319", "Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning"
runs = api.runs(f"{entity}/{project}")
len(runs)
# Out:
# 86

# %%
task_orders = ['1k', '10k', '100k', '500k', '1m', '2m', '5m', '10m']
dir_path_list_resnet50 = sort_tasks_by_size(glob.glob('../../models/ResNet50/*'), task_orders)
dir_path_list_FPN = sort_tasks_by_size(glob.glob('../../models/FPN/*'), task_orders)
dir_path_list_XCiT = sort_tasks_by_size(glob.glob('../../models/XCiT/*'), task_orders)
dir_path_list = dir_path_list_resnet50 + dir_path_list_FPN + dir_path_list_XCiT
task_names = [os.path.basename(dir_path) for dir_path in dir_path_list]
task_names
# Out:
# ['09052024-resnet50-dataset_v5_size-1k',
#  '09022024-resnet50-dataset_v5_size-10k',
#  '09082024-resnet50-dataset_v5_size-100k',
#  '09022024-resnet50-dataset_v5_size-500k',
#  '09022024-resnet50-dataset_v5_size-1m',
#  '09052024-resnet50-dataset_v5_size-2m',
#  '09032024-resnet50-dataset_v5_size-5m',
#  '09112024-resnet50-dataset_v5_size-10m',
#  '09232024-FPN-dataset_v5_size-1k',
#  '09232024-FPN-dataset_v5_size-10k',
#  '09242024-FPN-dataset_v5_size-100k',
#  '09252024-FPN-dataset_v5_size-500k',
#  '09252024-FPN-dataset_v5_size-1m',
#  '09262024-FPN-dataset_v5_size-2m',
#  '09272024-FPN-dataset_v5_size-5m',
#  '09282024-FPN-dataset_v5_size-10m',
#  '09232024-XCiT-dataset_v5_size-1k',
#  '09232024-XCiT-dataset_v5_size-10k',
#  '09302024-XCiT-dataset_v5_size-100k',
#  '09302024-XCiT-dataset_v5_size-500k',
#  '09302024-XCiT-dataset_v5_size-1m',
#  '09302024-XCiT-dataset_v5_size-2m',
#  '09302024-XCiT-dataset_v5_size-5m',
#  '09302024-XCiT-dataset_v5_size-10m']

# %%
# Loop over each run and fetch the history
for run in runs:
    if run.id in task_names:
        if os.path.exists(f"../../results/history/{run.id}_full_history.csv"):
            print(f"History already downloaded for run: {run.id}")
        else:
            print(f"Downloading history for run: {run.id}")

            # Use scan_history to avoid sampling
            all_data = []
            try:
                for step in run.scan_history(page_size=100):  # Fetch in chunks
                    all_data.append(step)
            except Exception as e:
                print(f"Error fetching history for {run.name}: {e}")
                continue

            # Convert to DataFrame
            if all_data:
                df = pd.DataFrame(all_data)

                # Save the complete history as CSV
                filename = f"../../results/history/{run.id}_full_history.csv"
                df.to_csv(filename, index=False)
                print(f"Saved full history to: {filename}")

                # Optional: Print part of the history to the console
                # print(df.tail())
            else:
                print(f"No data found for run: {run.name}")
# Out:
# History already downloaded for run: 09022024-resnet50-dataset_v5_size-10k
# History already downloaded for run: 09022024-resnet50-dataset_v5_size-500k
# History already downloaded for run: 09022024-resnet50-dataset_v5_size-1m
# History already downloaded for run: 09032024-resnet50-dataset_v5_size-5m
# History already downloaded for run: 09052024-resnet50-dataset_v5_size-2m
# History already downloaded for run: 09052024-resnet50-dataset_v5_size-1k
# History already downloaded for run: 09082024-resnet50-dataset_v5_size-100k
# History already downloaded for run: 09112024-resnet50-dataset_v5_size-10m
# History already downloaded for run: 09232024-FPN-dataset_v5_size-1k
# History already downloaded for run: 09232024-FPN-dataset_v5_size-10k
# History already downloaded for run: 09242024-FPN-dataset_v5_size-100k
# History already downloaded for run: 09252024-FPN-dataset_v5_size-500k
# Downloading history for run: 09252024-FPN-dataset_v5_size-1m
# Saved full history to: ../../results/history/09252024-FPN-dataset_v5_size-1m_full_history.csv
# Downloading history for run: 09262024-FPN-dataset_v5_size-2m
# Saved full history to: ../../results/history/09262024-FPN-dataset_v5_size-2m_full_history.csv
# Downloading history for run: 09272024-FPN-dataset_v5_size-5m
# Saved full history to: ../../results/history/09272024-FPN-dataset_v5_size-5m_full_history.csv
# Downloading history for run: 09282024-FPN-dataset_v5_size-10m
# Saved full history to: ../../results/history/09282024-FPN-dataset_v5_size-10m_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-100k
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-100k_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-500k
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-500k_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-1m
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-1m_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-2m
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-2m_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-5m
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-5m_full_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-10m
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# Saved full history to: ../../results/history/09302024-XCiT-dataset_v5_size-10m_full_history.csv
# Downloading history for run: 09232024-XCiT-dataset_v5_size-1k
# Saved full history to: ../../results/history/09232024-XCiT-dataset_v5_size-1k_full_history.csv
# Downloading history for run: 09232024-XCiT-dataset_v5_size-10k
# Saved full history to: ../../results/history/09232024-XCiT-dataset_v5_size-10k_full_history.csv

# %%
# Loop over each run and fetch the history
for run in runs:
    if run.group in ['dataset_v5_size_vs_records-XCiT', 'dataset_v5_size_vs_records']:
        print(f"Downloading history for run: {run.name} ({run.id})")

        # Use scan_history to avoid sampling
        all_data = []
        try:
            for step in run.scan_history(page_size=100):  # Fetch in chunks
                all_data.append(step)
        except Exception as e:
            print(f"Error fetching history for {run.name}: {e}")
            continue

        # Convert to DataFrame
        if all_data:
            df = pd.DataFrame(all_data)

            # Save the complete history as CSV
            filename = f"../../data/{run.id}_full_history.csv"
            df.to_csv(filename, index=False)
            print(f"Saved full history to: {filename}")

            # Optional: Print part of the history to the console
            print(df.tail())
        else:
            print(f"No data found for run: {run.name}")
# Out:
# Downloading history for run: 09022024-resnet50-dataset_v5_size-10k (09022024-resnet50-dataset_v5_size-10k)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       7 all_data = []
#       8 try:
# ----> 9     for step in run.scan_history(page_size=100):  # Fetch in chunks
#      10         all_data.append(step)
#      11 except Exception as e:
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/history.py:51, in HistoryScan.__next__(self)
#      49 if self.page_offset >= self.max_step:
#      50     raise StopIteration()
# ---> 51 self._load_next()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 message = "Whoa, you found a bug."
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      26 except requests.HTTPError as error:
#      27     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/history.py:73, in HistoryScan._load_next(self)
#      63     max_step = self.max_step
#      64 variables = {
#      65     "entity": self.run.entity,
#      66     "project": self.run.project,
#    (...)
#      70     "pageSize": int(self.page_size),
#      71 }
# ---> 73 res = self.client.execute(self.QUERY, variable_values=variables)
#      74 res = res["project"]["run"]["history"]
#      75 self.rows = [json.loads(row) for row in res]
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/api.py:72, in RetryingClient.execute(self, *args, **kwargs)
#      65 @retry.retriable(
#      66     retry_timedelta=RETRY_TIMEDELTA,
#      67     check_retry_fn=util.no_retry_auth,
#      68     retryable_exceptions=(RetryError, requests.RequestException),
#      69 )
#      70 def execute(self, *args, **kwargs):  # noqa: D102  # User not encouraged to use this class directly
#      71     try:
# ---> 72         return self._client.execute(*args, **kwargs)
#      73     except requests.exceptions.ReadTimeout:
#      74         if "timeout" not in kwargs:
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      49 if self.schema:
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#      54     raise Exception(str(result.errors[0]))
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      58 def _get_result(self, document, *args, **kwargs):
#      59     if not self.retries:
# ---> 60         return self.transport.execute(document, *args, **kwargs)
#      62     last_exception = None
#      63     retries_count = 0
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/gql_request.py:58, in GraphQLSession.execute(self, document, variable_values, timeout)
#      51 data_key = "json" if self.use_json else "data"
#      52 post_args = {
#      53     "headers": self.headers,
#      54     "cookies": self.cookies,
#      55     "timeout": timeout or self.default_timeout,
#      56     data_key: payload,
#      57 }
# ---> 58 request = self.session.post(self.url, **post_args)
#      59 request.raise_for_status()
#      61 result = request.json()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
history = run.scan_history(page_size=50)

# %%
all_data = []
for step in run.scan_history(page_size=100):  # Fetch in chunks
    all_data.append(step)
# Convert to DataFrame
if all_data:
    df = pd.DataFrame(all_data)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 all_data = []
# ----> 2 for step in run.scan_history(page_size=100):  # Fetch in chunks
#       3     all_data.append(step)
#       4 # Convert to DataFrame
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/history.py:51, in HistoryScan.__next__(self)
#      49 if self.page_offset >= self.max_step:
#      50     raise StopIteration()
# ---> 51 self._load_next()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 message = "Whoa, you found a bug."
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      26 except requests.HTTPError as error:
#      27     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/history.py:73, in HistoryScan._load_next(self)
#      63     max_step = self.max_step
#      64 variables = {
#      65     "entity": self.run.entity,
#      66     "project": self.run.project,
#    (...)
#      70     "pageSize": int(self.page_size),
#      71 }
# ---> 73 res = self.client.execute(self.QUERY, variable_values=variables)
#      74 res = res["project"]["run"]["history"]
#      75 self.rows = [json.loads(row) for row in res]
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/api.py:72, in RetryingClient.execute(self, *args, **kwargs)
#      65 @retry.retriable(
#      66     retry_timedelta=RETRY_TIMEDELTA,
#      67     check_retry_fn=util.no_retry_auth,
#      68     retryable_exceptions=(RetryError, requests.RequestException),
#      69 )
#      70 def execute(self, *args, **kwargs):  # noqa: D102  # User not encouraged to use this class directly
#      71     try:
# ---> 72         return self._client.execute(*args, **kwargs)
#      73     except requests.exceptions.ReadTimeout:
#      74         if "timeout" not in kwargs:
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      49 if self.schema:
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#      54     raise Exception(str(result.errors[0]))
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      58 def _get_result(self, document, *args, **kwargs):
#      59     if not self.retries:
# ---> 60         return self.transport.execute(document, *args, **kwargs)
#      62     last_exception = None
#      63     retries_count = 0
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/sdk/lib/gql_request.py:58, in GraphQLSession.execute(self, document, variable_values, timeout)
#      51 data_key = "json" if self.use_json else "data"
#      52 post_args = {
#      53     "headers": self.headers,
#      54     "cookies": self.cookies,
#      55     "timeout": timeout or self.default_timeout,
#      56     data_key: payload,
#      57 }
# ---> 58 request = self.session.post(self.url, **post_args)
#      59 request.raise_for_status()
#      61 result = request.json()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
history = run.scan_history(keys=["train_loss", "train_accuracy"], page_size=100)
history

# %%
# Use scan_history to avoid sampling
all_data = []
try:
    for step in history:  # Fetch in chunks
        all_data.append(step)
except Exception as e:
    print(f"Error fetching history for {run.name}: {e}")

# Convert to DataFrame
if all_data:
    df = pd.DataFrame(all_data)

# %%
df
# Out:
#        train_loss  train_accuracy
# 0        3.124663        0.056842
# 1        3.110478        0.056579
# 2        3.072398        0.057851
# 3        3.112467        0.056839
# 4        3.099236        0.062895
# ...           ...             ...
# 10124    0.033219        0.989262
# 10125    0.033041        0.988947
# 10126    0.036204        0.988158
# 10127    0.023357        0.991736
# 10128    0.033350        0.988912
#
# [10129 rows x 2 columns]

# %%
runs[0].name
# Out:
# '09232024-XCiT-dataset_v5_size-1k'

# %%
# Loop through all runs and save their histories
for run in runs:
    if run.group in ['dataset_v5_size_vs_records-XCiT', 'dataset_v5_size_vs_records']:
        print(f"Downloading history for run: {run.name} ({run.id})")
        history = run.history()  # Get all metrics
        filename = f"../../data/{run.name}_{run.id}_history.csv"
        history.to_csv(filename, index=False)
        print(f"--Saved: {filename}")
# Out:
# Downloading history for run: 09232024-XCiT-dataset_v5_size-1k (09232024-XCiT-dataset_v5_size-1k)
# --Saved: ../../data/09232024-XCiT-dataset_v5_size-1k_09232024-XCiT-dataset_v5_size-1k_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-10m (09302024-XCiT-dataset_v5_size-10m)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-10m_09302024-XCiT-dataset_v5_size-10m_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-5m (09302024-XCiT-dataset_v5_size-5m)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-5m_09302024-XCiT-dataset_v5_size-5m_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-2m (09302024-XCiT-dataset_v5_size-2m)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-2m_09302024-XCiT-dataset_v5_size-2m_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-1m (09302024-XCiT-dataset_v5_size-1m)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-1m_09302024-XCiT-dataset_v5_size-1m_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-500k (09302024-XCiT-dataset_v5_size-500k)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-500k_09302024-XCiT-dataset_v5_size-500k_history.csv
# Downloading history for run: 09302024-XCiT-dataset_v5_size-100k (09302024-XCiT-dataset_v5_size-100k)
# --Saved: ../../data/09302024-XCiT-dataset_v5_size-100k_09302024-XCiT-dataset_v5_size-100k_history.csv
# Downloading history for run: 09112024-resnet50-dataset_v5_size-10m (09112024-resnet50-dataset_v5_size-10m)
# --Saved: ../../data/09112024-resnet50-dataset_v5_size-10m_09112024-resnet50-dataset_v5_size-10m_history.csv
# Downloading history for run: 09082024-resnet50-dataset_v5_size-100k (09082024-resnet50-dataset_v5_size-100k)
# --Saved: ../../data/09082024-resnet50-dataset_v5_size-100k_09082024-resnet50-dataset_v5_size-100k_history.csv
# Downloading history for run: 09052024-resnet50-dataset_v5_size-1k (09052024-resnet50-dataset_v5_size-1k)
# --Saved: ../../data/09052024-resnet50-dataset_v5_size-1k_09052024-resnet50-dataset_v5_size-1k_history.csv
# Downloading history for run: 09052024-resnet50-dataset_v5_size-2m (09052024-resnet50-dataset_v5_size-2m)
# --Saved: ../../data/09052024-resnet50-dataset_v5_size-2m_09052024-resnet50-dataset_v5_size-2m_history.csv
# Downloading history for run: 09032024-resnet50-dataset_v5_size-5m (09032024-resnet50-dataset_v5_size-5m)
# --Saved: ../../data/09032024-resnet50-dataset_v5_size-5m_09032024-resnet50-dataset_v5_size-5m_history.csv
# Downloading history for run: 09022024-resnet50-dataset_v5_size-1m (09022024-resnet50-dataset_v5_size-1m)
# --Saved: ../../data/09022024-resnet50-dataset_v5_size-1m_09022024-resnet50-dataset_v5_size-1m_history.csv
# Downloading history for run: 09022024-resnet50-dataset_v5_size-500k (09022024-resnet50-dataset_v5_size-500k)
# --Saved: ../../data/09022024-resnet50-dataset_v5_size-500k_09022024-resnet50-dataset_v5_size-500k_history.csv
# Downloading history for run: 09022024-resnet50-dataset_v5_size-100k (09022024-resnet50-dataset_v5_size-100k)
# --Saved: ../../data/09022024-resnet50-dataset_v5_size-100k_09022024-resnet50-dataset_v5_size-100k_history.csv
# Downloading history for run: 09022024-resnet50-dataset_v5_size-10k (09022024-resnet50-dataset_v5_size-10k)
# --Saved: ../../data/09022024-resnet50-dataset_v5_size-10k_09022024-resnet50-dataset_v5_size-10k_history.csv

# %%
history
# Out:
#          _runtime  train_loss     records   epoch  train_accuracy  \
# 0      212.407909    3.049765     59008.0     NaN        0.060000
# 1      246.956756    3.120529      3800.0     NaN        0.061053
# 2      272.584560    3.101461     25704.0     NaN        0.060950
# 3      335.648462    3.089459     68544.0     NaN        0.056818
# 4      397.266604    3.036275    110416.0     NaN        0.065526
# ..            ...         ...         ...     ...             ...
# 495  43951.565907         NaN  21227632.0     NaN             NaN
# 496  44110.756370    0.029406  21303848.0     NaN        0.990000
# 497  44169.363914    0.032084         NaN  2492.0        0.989379
# 498  44246.242677    0.033219         NaN  2499.0        0.989262
# 499  44313.881630         NaN  21521632.0     NaN             NaN
#
#        _timestamp  valid_accuracy  valid_noise_accuracy  valid_loss  \
# 0    1.725337e+09             NaN                   NaN         NaN
# 1    1.725337e+09             NaN                   NaN         NaN
# 2    1.725337e+09             NaN                   NaN         NaN
# 3    1.725337e+09             NaN                   NaN         NaN
# 4    1.725338e+09             NaN                   NaN         NaN
# ..            ...             ...                   ...         ...
# 495  1.725381e+09             NaN              0.139737         NaN
# 496  1.725381e+09             NaN                   NaN         NaN
# 497  1.725381e+09             NaN                   NaN         NaN
# 498  1.725381e+09             NaN                   NaN         NaN
# 499  1.725381e+09             NaN                   NaN         NaN
#
#      valid_atom_loss  valid_noise_loss  valid_atom_accuracy  _step
# 0                NaN               NaN                  NaN     25
# 1                NaN               NaN                  NaN     30
# 2                NaN               NaN                  NaN     40
# 3                NaN               NaN                  NaN     60
# 4                NaN               NaN                  NaN     79
# ..               ...               ...                  ...    ...
# 495              NaN          5.431292                  NaN  18324
# 496              NaN               NaN                  NaN  18389
# 497              NaN               NaN                  NaN  18412
# 498              NaN               NaN                  NaN  18440
# 499         4.654116               NaN             0.347105  18475
#
# [500 rows x 13 columns]

# %%
# Store run information in a DataFrame
import pandas as pd
summary_list = [run.summary._json_dict for run in runs]
config_list = [{k: v for k, v in run.config.items() if not k.startswith("_")} for run in runs]
name_list = [run.name for run in runs]

# Combine into a DataFrame and save as CSV
df = pd.DataFrame({"summary": summary_list, "config": config_list, "name": name_list})
df.to_csv("run_history.csv", index=False)

# %%
df['summary'][0], df['config'][0], df['name'][0]
# Out:
# ({'_runtime': 1109.45472240448,
#   '_step': 439,
#   '_timestamp': 1729822171.2712643,
#   'epoch': 220,
#   'records': 188540,
#   'train_accuracy': 0.9801633605600932,
#   'train_loss': 0.05298442393541336},
#  {'dataset': '1k datasets',
#   'loss_func': 'CrossEntropyLoss',
#   'optimizer': 'Adam',
#   'scheduler': 'OneCycleLR'},
#  '09232024-XCiT-dataset_v5_size-1k')

# %%
run = runs[0]
run.history()
# Out:
#       _step  train_accuracy   records  train_loss     _runtime    _timestamp  \
# 0         0        0.072345     857.0    3.024270   128.760875  1.729821e+09
# 1         1        0.072345       NaN    3.024270   129.017427  1.729821e+09
# 2         2        0.081680    1714.0    2.837516   133.973591  1.729821e+09
# 3         3        0.081680       NaN    2.837516   134.355553  1.729821e+09
# 4         4        0.108518    2571.0    2.772935   138.973066  1.729821e+09
# ...     ...             ...       ...         ...          ...           ...
# 2064   2064        1.000000       NaN    0.000964  4158.950707  1.729825e+09
# 2065   2065        0.998833  731021.0    0.001898  4163.015741  1.729825e+09
# 2066   2066        0.998833       NaN    0.001898  4163.277447  1.729825e+09
# 2067   2067        1.000000  731878.0    0.000734  4167.322429  1.729825e+09
# 2068   2068        1.000000       NaN    0.000734  4167.604550  1.729825e+09
#
#       epoch  valid_loss  valid_accuracy  valid_atom_loss  valid_atom_accuracy  \
# 0       NaN         NaN             NaN              NaN                  NaN
# 1       1.0         NaN             NaN              NaN                  NaN
# 2       NaN         NaN             NaN              NaN                  NaN
# 3       2.0         NaN             NaN              NaN                  NaN
# 4       NaN         NaN             NaN              NaN                  NaN
# ...     ...         ...             ...              ...                  ...
# 2064  852.0         NaN             NaN              NaN                  NaN
# 2065    NaN         NaN             NaN              NaN                  NaN
# 2066  853.0         NaN             NaN              NaN                  NaN
# 2067    NaN         NaN             NaN              NaN                  NaN
# 2068  854.0         NaN             NaN              NaN                  NaN
#
#       valid_noise_accuracy  valid_noise_loss
# 0                      NaN               NaN
# 1                      NaN               NaN
# 2                      NaN               NaN
# 3                      NaN               NaN
# 4                      NaN               NaN
# ...                    ...               ...
# 2064                   NaN               NaN
# 2065                   NaN               NaN
# 2066                   NaN               NaN
# 2067                   NaN               NaN
# 2068                   NaN               NaN
#
# [2069 rows x 13 columns]

# %%
run.group
# Out:
# 'dataset_v5_size_vs_records-XCiT'

# %%
for run in runs:
    print(f"Fetching complete history for run: {run.name} ({run.id})")
# Out:
# Fetching complete history for run: 09232024-XCiT-dataset_v5_size-1k (09232024-XCiT-dataset_v5_size-1k)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-10m (09302024-XCiT-dataset_v5_size-10m)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-5m (09302024-XCiT-dataset_v5_size-5m)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-2m (09302024-XCiT-dataset_v5_size-2m)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-1m (09302024-XCiT-dataset_v5_size-1m)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-500k (09302024-XCiT-dataset_v5_size-500k)
# Fetching complete history for run: 09302024-XCiT-dataset_v5_size-100k (09302024-XCiT-dataset_v5_size-100k)
# Fetching complete history for run: 09282024-FPN-dataset_v5_size-10m (09282024-FPN-dataset_v5_size-10m)
# Fetching complete history for run: 09272024-FPN-dataset_v5_size-5m (09272024-FPN-dataset_v5_size-5m)
# Fetching complete history for run: 09262024-FPN-dataset_v5_size-2m (09262024-FPN-dataset_v5_size-2m)
# Fetching complete history for run: 09252024-FPN-dataset_v5_size-1m (09252024-FPN-dataset_v5_size-1m)
# Fetching complete history for run: 09252024-FPN-dataset_v5_size-500k (09252024-FPN-dataset_v5_size-500k)
# Fetching complete history for run: 09242024-FPN-dataset_v5_size-100k (09242024-FPN-dataset_v5_size-100k)
# Fetching complete history for run: 09232024-FPN-dataset_v5_size-10k (09232024-FPN-dataset_v5_size-10k)
# Fetching complete history for run: 09232024-FPN-dataset_v5_size-1k (09232024-FPN-dataset_v5_size-1k)
# Fetching complete history for run: 09112024-resnet50-dataset_v5_size-10m (09112024-resnet50-dataset_v5_size-10m)
# Fetching complete history for run: 09082024-resnet50-dataset_v5_size-100k (09082024-resnet50-dataset_v5_size-100k)
# Fetching complete history for run: 09052024-resnet50-dataset_v5_size-1k (09052024-resnet50-dataset_v5_size-1k)
# Fetching complete history for run: 09052024-resnet50-dataset_v5_size-2m (09052024-resnet50-dataset_v5_size-2m)
# Fetching complete history for run: 09032024-resnet50-dataset_v5_size-5m (09032024-resnet50-dataset_v5_size-5m)
# Fetching complete history for run: 09022024-resnet50-dataset_v5_size-1m (09022024-resnet50-dataset_v5_size-1m)
# Fetching complete history for run: 09022024-resnet50-dataset_v5_size-500k (09022024-resnet50-dataset_v5_size-500k)
# Fetching complete history for run: 09022024-resnet50-dataset_v5_size-100k (09022024-resnet50-dataset_v5_size-100k)
# Fetching complete history for run: 09022024-resnet50-dataset_v5_size-10k (09022024-resnet50-dataset_v5_size-10k)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-5m (08282024-resnet50-dataset_v5_size-5m)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-2m (08282024-resnet50-dataset_v5_size-2m)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-1m (08282024-resnet50-dataset_v5_size-1m)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-500k (08282024-resnet50-dataset_v5_size-500k)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-100k (08282024-resnet50-dataset_v5_size-100k)
# Fetching complete history for run: 08282024-resnet50-dataset_v5_size-10k (08282024-resnet50-dataset_v5_size-10k-new)
# Fetching complete history for run: 08022024-benchmark-vit_base-v4_10m-DDP-shenron (08022024-benchmark-vit_base-v4_10m-DDP-shenron)
# Fetching complete history for run: 07302024-benchmark-XCiT-v4_10m-DDP (07302024-benchmark-XCiT-v4_10m-DDP)
# Fetching complete history for run: 07282024-benchmark-XCiT-v4_10m (07282024-benchmark-XCiT-v4_10m)
# Fetching complete history for run: 07252024-benchmark-ViT_from_scratch-v5_10m (07252024-benchmark-ViT_from_scratch-v5_10m)
# Fetching complete history for run: 06272024-benchmark-crossvit_from_scratch-v5_10m-m3kube (06272024-benchmark-crossvit_from_scratch-v5_10m-m3kube)
# Fetching complete history for run: 06272024-benchmark-crossvit_from_scratch-v5_10m (06272024-benchmark-crossvit_from_scratch-v5_10m)
# Fetching complete history for run: 06272024-benchmark-ViT_from_scratch-v5_10m (06272024-benchmark-ViT_from_scratch-v5_10m)
# Fetching complete history for run: 06212024-benchmark-resnet50_from_scratch-imagenet_crop_gradient_atom_v5_1m (06212024-benchmark-resnet50_from_scratch-imagenet_crop_gradient_atom_v5_1m)
# Fetching complete history for run: 06212024-benchmark-resnet50_from_scratch-imagenet_crop_atom_v5_1m (06212024-benchmark-resnet50_from_scratch-imagenet_crop_atom_v5_1m)
# Fetching complete history for run: 06132024-benchmark-resnet50_from_scratch-imagenet_bg_atom_v5_1m_blend (06132024-benchmark-resnet50_from_scratch-imagenet_bg_atom_v5_1m_blend)
# Fetching complete history for run: 06132024-benchmark-resnet50_from_scratch-imagenet_bg_atom_v5_1m (06132024-benchmark-resnet50_from_scratch-imagenet_bg_atom_v5_1m)
# Fetching complete history for run: 05242024-benchmark-resnet50_from_scratch-v5_10m (05242024-benchmark-resnet50_from_scratch-v5_10m)
# Fetching complete history for run: 05162024-DeepKAN (05162024-DeepKAN)
# Fetching complete history for run: 04152024-benchmark-resnet50_from_scratch-v5_1m (04152024-benchmark-resnet50_from_scratch-v5_1m)
# Fetching complete history for run: ResNet34_MultiKernel_large_rot_conv2d-1m-optimized (ResNet34_MultiKernel_large_rot_conv2d-1m-optimized)
# Fetching complete history for run: ResNet34_MultiKernel_large_rot_conv2d-10m (ResNet34_MultiKernel_large_rot_conv2d-10m)
# Fetching complete history for run: ResNet34_MultiKernel_rot_conv2d_fixed-10m (ResNet34_MultiKernel_rot_conv2d_fixed-10m)
# Fetching complete history for run: ResNet50_2m_symmetry_filter_preprocessed_rot2346f (ResNet50_2m_symmetry_filter_preprocessed_rot2346f)
# Fetching complete history for run: ResNet34_MultiKernel_rot_conv2d-10m (ResNet34_MultiKernel_rot_conv2d-10m)
# Fetching complete history for run: ResNet50_100k_symmetry_filter_preprocessed_rot2346f (ResNet50_100k_symmetry_filter_preprocessed_rot2346f)
# Fetching complete history for run: ResNet50_100K_subset_preprocessed_rot2346f (ResNet50_100K_subset_preprocessed_rot2346f)
# Fetching complete history for run: ResNet50_rot_conv2d_reg-100K_subset (ResNet50_rot_conv2d_reg-100K_subset)
# Fetching complete history for run: ResNet50_rot_conv2d_reg-10m (ResNet50_rot_conv2d_reg-10m)
# Fetching complete history for run: ResNet50_rot2346f_keep_original_conv2d-100K_subset (ResNet50_rot2346f_keep_original_conv2d-100K_subset)
# Fetching complete history for run: ResNet50_rot2f_conv2d-100K_subset (ResNet50_rot2f_conv2d-100K_subset)
# Fetching complete history for run: ResNet50_rot_conv2d-100K_subset (ResNet50_rot_conv2d-100K_subset)
# Fetching complete history for run: XCiT_medium-100K_subset (XCiT_medium-100K_subset)
# Fetching complete history for run: ResNet50-100K_subset (ResNet50-100K_subset)
# Fetching complete history for run: XCiT-100K_subset (XCiT-100K_subset)
# Fetching complete history for run: DenseNet161-100K_subset (DenseNet161-100K_subset)
# Fetching complete history for run: FPN-100K_subset (FPN-100K_subset)
# Fetching complete history for run: 02292024-resnet50_conv1_layer1_classifier-atom_noised_2m (vnxp71j6)
# Fetching complete history for run: 02292024-finetune_resnet50_conv1_layer1-atom_noised_2m (f97nxjsu)
# Fetching complete history for run: 02292024-finetune_early_block-atom_noised_2m (1ek7jxu0)
# Fetching complete history for run: 02292024-finetune_early_block-atom_noised_2m (fx8smaax)
# Fetching complete history for run: 02292024-resnet50-finetune_first_layer-finetune_atom_noised_2m (0tdcpa56)
# Fetching complete history for run: 02292024-resnet50-finetune_first_layer-finetune_atom_noised_2m (pse7lpl0)
# Fetching complete history for run: 02292024-resnet50-finetune_first_layer-finetune_atom_noised_2m (pckfu8yj)
# Fetching complete history for run: 02292024-resnet50-finetune_first_layer-finetune_atom_noised_2m (tqy6rw2w)
# Fetching complete history for run: 01102024-benchmark-resnet50_from_scratch-v4_10m-finetune_atom_first_layer (av7pggf3)
# Fetching complete history for run: 01102024-benchmark-resnet50_from_scratch-v4_10m-finetune_atom_first_layer (01102024-benchmark-resnet50_from_scratch-v4_10m-finetune_atom_first_layer)
# Fetching complete history for run: 01102024-benchmark-resnet50_from_scratch-v4_10m-finetune_atom (01102024-benchmark-resnet50_from_scratch-v4_10m-finetune_atom)
# Fetching complete history for run: preprocess-fft_radon_stacked (vghuvyej)
# Fetching complete history for run: preprocess-fft_magnitude_spectrum (7q5yz16l)
# Fetching complete history for run: preprocess-fft_magnitude_spectrum (0k8wjzci)
# Fetching complete history for run: preprocess-radon (preprocess-radon)
# Fetching complete history for run: preprocess-fft_phase_spectrum (preprocess-fft_phase_spectrum)
# Fetching complete history for run: 01182024-benchmark-fpn_resnet50-v4_10m (01182024-benchmark-fpn_resnet50-v4_10m-2)
# Fetching complete history for run: Train_Noise-CrossValidate_ImageNet (Train_Noise-CrossValidate_ImageNet)
# Fetching complete history for run: Train_Noise-CrossValidate_Atom (Train_Noise-CrossValidate_Atom)
# Fetching complete history for run: Train_ImageNet-CrossValidate_Noise (Train_ImageNet-CrossValidate_Noise)
# Fetching complete history for run: Train_ImageNet-CrossValidate_Atom (Train_ImageNet-CrossValidate_Atom)
# Fetching complete history for run: Train_Atom-CrossValidate_Noise (Train_Atom-CrossValidate_Noise)
# Fetching complete history for run: Train_Atom-CrossValidate_ImageNet (Train_Atom-CrossValidate_ImageNet)
# Fetching complete history for run: 01122024-benchmark-DenseNet161-v4_10m (01122024-benchmark-DenseNet161-v4_10m)
# Fetching complete history for run: 01102024-benchmark-XCiT-v4_10m (01102024-benchmark-XCiT-v4_10m)

# %%
history = run.scan_history(keys=None, page_size=100)
history = list(history)
len(history)
# Out:
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 history = run.scan_history(keys=None, page_size=100)
# ----> 2 history = list(history)
#       3 len(history)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/apis/public/history.py:50, in HistoryScan.__next__(self)
#      48 if self.page_offset >= self.max_step:
#      49     raise StopIteration()
# ---> 50 self._load_next()
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/apis/public/history.py:72, in HistoryScan._load_next(self)
#      62     max_step = self.max_step
#      63 variables = {
#      64     "entity": self.run.entity,
#      65     "project": self.run.project,
#    (...)
#      69     "pageSize": int(self.page_size),
#      70 }
# ---> 72 res = self.client.execute(self.QUERY, variable_values=variables)
#      73 res = res["project"]["run"]["history"]
#      74 self.rows = [json.loads(row) for row in res]
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/apis/public/api.py:73, in RetryingClient.execute(self, *args, **kwargs)
#      66 @retry.retriable(
#      67     retry_timedelta=RETRY_TIMEDELTA,
#      68     check_retry_fn=util.no_retry_auth,
#      69     retryable_exceptions=(RetryError, requests.RequestException),
#      70 )
#      71 def execute(self, *args, **kwargs):
#      72     try:
# ---> 73         return self._client.execute(*args, **kwargs)
#      74     except requests.exceptions.ReadTimeout:
#      75         if "timeout" not in kwargs:
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      49 if self.schema:
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#      54     raise Exception(str(result.errors[0]))
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      58 def _get_result(self, document, *args, **kwargs):
#      59     if not self.retries:
# ---> 60         return self.transport.execute(document, *args, **kwargs)
#      62     last_exception = None
#      63     retries_count = 0
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/wandb/sdk/lib/gql_request.py:58, in GraphQLSession.execute(self, document, variable_values, timeout)
#      51 data_key = "json" if self.use_json else "data"
#      52 post_args = {
#      53     "headers": self.headers,
#      54     "cookies": self.cookies,
#      55     "timeout": timeout or self.default_timeout,
#      56     data_key: payload,
#      57 }
# ---> 58 request = self.session.post(self.url, **post_args)
#      59 request.raise_for_status()
#      61 result = request.json()
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
history

# %%
history = run.scan_history(page_size=100)

# %%
# Loop through all runs and save their histories
for run in runs:
    print(f"Downloading history for run: {run.name} ({run.id})")
    
    # Retrieve full history of the run
    history = run.history(keys=None, pandas=True)  # Get all metrics

    # Save each run's history as a CSV
    filename = f"{run.name}_{run.id}_history.csv"
    history.to_csv(filename, index=False)
    print(f"Saved: {filename}")

# %%
import wandb
run = wandb.init()
artifact = run.use_artifact('yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning/run-09302024-XCiT-dataset_v5_size-2m-history:v0', type='wandb-history')
artifact_dir = artifact.download()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: yig319. Use `wandb login --relogin` to force relogin
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/scratch/home/yichen/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root/notebooks/various_dataset_size/wandb/run-20241025_020754-2jhxenkm</code>
# Syncing run <strong><a href='https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size/runs/2jhxenkm' target="_blank">dainty-pyramid-1</a></strong> to <a href='https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size' target="_blank">https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size</a>
#  View run at <a href='https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size/runs/2jhxenkm' target="_blank">https://wandb.ai/yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root-notebooks_various_dataset_size/runs/2jhxenkm</a>
# wandb:   1 of 1 files downloaded.

# %%
artifact_dir
# Out:
# '/scratch/home/yichen/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning_root/notebooks/various_dataset_size/artifacts/run-09302024-XCiT-dataset_v5_size-2m-history:v0'

# %%
import wandb
api = wandb.Api()

# run is specified by <entity>/<project>/<run_id>
path_root = "yig319/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning"
run = api.run(f"{path_root}/09052024-resnet50-dataset_v5_size-2m")

if run.state == "finished":
    for i, row in run.history().iterrows():
        print(row["epoch"], row["train_loss"])
      
# # save the metrics for the run to a csv file
# metrics_dataframe = run.history()
# metrics_dataframe.to_csv("metrics.csv")

# metrics_dataframe
# Out:
# nan 3.058157444000244
# nan 2.9706921577453613
# nan 2.871853828430176
# nan 2.876805543899536
# nan 2.853511333465576
# nan 2.803056001663208
# nan nan
# nan nan
# nan nan
# nan 2.7910327911376953
# nan 2.7551069259643555
# nan 2.727480411529541
# nan 2.5953216552734375
# nan 2.5765514373779297
# nan 2.520590305328369
# nan 2.2497990131378174
# nan 1.719841718673706
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# 2.0 nan
# nan 1.6773067712783813
# nan 1.6742660999298096
# nan 1.713780403137207
# nan 1.4029533863067627
# nan 1.2173570394515991
# nan 1.2064590454101562
# nan 0.9871243834495544
# nan 0.903596043586731
# nan nan
# nan nan
# nan nan
# nan 0.7454651594161987
# nan 0.7169004082679749
# nan 0.6891512274742126
# nan 0.6809580326080322
# nan 0.6269720196723938
# nan 0.6091745495796204
# nan 0.5803536772727966
# nan 0.5600156188011169
# nan 0.5481707453727722
# nan nan
# nan nan
# nan nan
# nan 0.5173709988594055
# nan 0.4474424123764038
# nan 0.4510074257850647
# nan 0.45706191658973694
# nan 0.43071579933166504
# nan 0.3881348669528961
# nan 0.4155249297618866
# nan 0.38683611154556274
# nan 0.379555344581604
# nan nan
# nan nan
# nan 0.49330660700798035
# nan 0.3267397880554199
# nan 0.30022716522216797
# nan 0.2881677448749542
# nan 0.25618475675582886
# nan 0.24392609298229218
# nan 0.24880599975585938
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.29888537526130676
# nan 0.2607695758342743
# nan 0.2592141032218933
# nan 0.28331464529037476
# nan 0.2590740919113159
# nan 0.23351390659809113
# nan 0.2215113490819931
# nan nan
# nan nan
# nan 0.37720736861228943
# nan 0.3633381128311157
# nan 0.3044590950012207
# nan 0.2264908105134964
# nan 0.22795496881008148
# nan 0.20012204349040985
# nan 0.21359510719776154
# nan 0.20293816924095154
# nan 0.19536520540714264
# nan 0.193699449300766
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.8038585186004639
# nan 0.6266268491744995
# nan 0.33667823672294617
# nan 0.33034801483154297
# nan 0.3169400095939636
# nan 0.24409766495227814
# nan nan
# nan nan
# 9.0 nan
# nan 0.2228366881608963
# nan 0.22412393987178802
# nan 0.19822001457214355
# nan 0.18974748253822327
# nan 0.18429674208164215
# nan 0.15809482336044312
# nan nan
# nan nan
# nan nan
# nan nan
# 10.0 nan
# nan 0.47688573598861694
# nan 0.3690195381641388
# nan 0.2232023924589157
# nan 0.18864060938358307
# nan 0.1706790328025818
# nan 0.1777188777923584
# nan 0.18521533906459808
# nan 0.17041939496994019
# nan 0.13955514132976532
# nan 0.15014594793319702
# nan 0.162161722779274
# nan 0.1478193700313568
# nan nan
# nan nan
# nan nan
# nan 0.2682279646396637
# nan 0.27175426483154297
# nan 0.18093761801719666
# nan 0.15788741409778595
# nan 0.1315697431564331
# nan 0.13312667608261108
# nan 0.11954785883426666
# nan 0.1265406310558319
# nan 0.1363452970981598
# nan 0.11882885545492172
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.5057723522186279
# nan 0.33162766695022583
# nan 0.22897174954414368
# nan 0.20180334150791168
# nan 0.19133193790912628
# nan 0.13964445888996124
# nan 0.15035788714885712
# nan 0.15224318206310272
# nan 0.15196646749973297
# nan 0.14609195291996002
# nan 0.12921042740345
# nan 0.1313963681459427
# nan nan
# nan 0.262338250875473
# nan 0.15008141100406647
# nan 0.1306314468383789
# nan 0.11386661976575851
# nan 0.10656695067882538
# nan 0.11811384558677673
# nan 0.10357021540403366
# nan 0.11918749660253525
# nan 0.12177596241235733
# nan 0.11299531906843185
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 1.71802818775177
# nan 0.6119542121887207
# nan 0.3265599012374878
# nan 0.20226536691188812
# nan 0.1540820598602295
# nan 0.14021560549736023
# nan 0.14598728716373444
# nan 0.15118268132209778
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.7019540667533875
# nan 0.16759619116783142
# nan 0.1606118232011795
# nan 0.1209401935338974
# nan 0.13606730103492737
# nan 0.13923177123069763
# nan 0.14242662489414215
# nan 0.13137762248516083
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.31575632095336914
# nan 0.1917116343975067
# nan 0.11588221043348312
# nan 0.12078892439603806
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.5992568135261536
# nan 0.21181625127792358
# nan 0.16292083263397217
# nan 0.15421359241008759
# nan 0.1280578076839447
# nan 0.11497639864683151
# nan 0.11063095927238464
# nan 0.10211654007434845
# nan 0.10251196473836899
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.11594951152801514
# nan 0.10812561959028244
# nan 0.09897822886705399
# nan 0.11244860291481018
# nan 0.10274675488471985
# nan 0.08893107622861862
# nan 0.09484406560659409
# nan 0.08715939521789551
# nan 0.086578369140625
# nan 0.08499301224946976
# nan 0.09128469973802567
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.3716299831867218
# nan 0.16233453154563904
# nan 0.14260606467723846
# nan 0.1190858855843544
# nan 0.10059406608343124
# nan 0.09561366587877274
# nan 0.08327633887529373
# nan 0.08541279286146164
# nan 0.08002322912216187
# nan 0.09477540850639343
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.30799543857574463
# nan 0.10143528133630753
# nan 0.09544144570827484
# nan 0.0724177360534668
# nan 0.07011145353317261
# nan 0.06544292718172073
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 1.0935081243515015
# nan 0.1310899406671524
# nan 0.10456372052431107
# nan 0.09393911808729172
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.08015187829732895
# nan 0.08200474083423615
# nan 0.08959166705608368
# nan 0.06337383389472961
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.12922345101833344
# nan 0.07407181710004807
# nan 0.0742911621928215
# nan 0.07593856006860733
# nan 0.06953451782464981
# nan 0.06435073167085648
# nan 0.0801185891032219
# nan 0.06610511988401413
# nan 0.07651518285274506
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# 24.0 nan
# nan 0.13475684821605682
# nan 0.07943300902843475
# nan 0.09568294137716293
# nan 0.08407842367887497
# nan 0.08707067370414734
# nan 0.06233939155936241
# nan 0.05188422650098801
# nan 0.06589563190937042
# nan 0.07477190345525742
# nan 0.0688243955373764
# nan nan
# nan nan
# nan nan
# nan 0.1923849880695343
# nan 0.12264847010374069
# nan 0.08331532776355743
# nan 0.07595232874155045
# nan 0.08653415739536285
# nan 0.054415084421634674
# nan 0.0613849014043808
# nan 0.056116294115781784
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.18607500195503235
# nan 0.08536352962255478
# nan 0.066001757979393
# nan 0.06563375145196915
# nan 0.05459945648908615
# nan 0.05770182982087135
# nan 0.04741958901286125
# nan 0.050370823591947556
# nan 0.038222312927246094
# nan 0.06480131298303604
# nan nan
# nan nan
# nan nan
# nan 0.5575517416000366
# nan 0.1328626573085785
# nan 0.11164935678243637
# nan 0.06097301095724106
# nan 0.0843857079744339
# nan 0.07030264288187027
# nan 0.06835203617811203
# nan 0.04692850634455681
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.11142802983522415
# nan 0.06778385490179062
# nan 0.05853355675935745
# nan 0.05037587508559227
# nan 0.05559610575437546
# nan 0.058924172073602676
# nan 0.05863843113183975
# nan 0.052510835230350494
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.12716630101203918
# nan 0.08737214654684067
# nan 0.05070628225803375
# nan 0.06575970351696014
# nan 0.0609896294772625
# nan 0.03782811760902405
# nan 0.03871341794729233
# nan 0.04081888124346733
# nan nan
# nan nan
# nan nan
# nan 0.09990917146205902
# nan 0.07542722672224045
# nan 0.04319936782121658
# nan 0.03468653932213783
# nan 0.040327977389097214
# nan 0.03686075285077095
# nan 0.0360298790037632
# nan 0.03649169206619263
# nan 0.04188796132802963
# nan 0.038788821548223495
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.07352706789970398
# nan 0.07309611141681671
# nan 0.05788256600499153
# nan 0.0455516055226326
# nan 0.04094645753502846
# nan 0.04214564338326454
# nan 0.03130142018198967
# nan 0.03744027763605118
# nan 0.035110510885715485
# nan 0.09419866651296616
# nan 0.051258549094200134
# nan 0.02856154553592205
# nan 0.04488162696361542
# nan 0.05914769321680069
# nan 0.04104937985539436
# nan 0.031459443271160126
# nan 0.03757629543542862
# nan 0.03622262924909592
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.05617993324995041
# nan 0.04631752520799637
# nan 0.03358835354447365
# nan 0.03934866189956665
# nan 0.04089656099677086
# nan 0.037694744765758514
# nan 0.03580173850059509
# nan 0.04604388773441315
# nan 0.03154527395963669
# nan 0.029806561768054962
# nan 0.025263741612434387
# nan 0.03661626949906349
# nan nan
# nan nan
# nan nan
# nan 0.04306795075535774
# nan 0.027939828112721443
# nan 0.04368215426802635
# nan 0.03596070781350136
# nan 0.033185794949531555
# nan 0.03682659938931465
# nan 0.022407421842217445
# nan 0.03164970874786377
# nan 0.037040747702121735
# nan nan
# nan nan
# nan nan
# 35.0 nan
# nan 0.041301146149635315
# nan 0.036447737365961075
# nan 0.035114698112010956
# nan 0.030129697173833847
# nan 0.03139907866716385
# nan 0.020131489261984825
# nan 0.03722323477268219
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan 0.03623674064874649
# nan 0.03777239844202995
# nan 0.04284941777586937
# nan 0.0249463003128767
# nan 0.0379144661128521
# nan 0.023331211879849434
# nan 0.025440197438001633
# nan 0.023299336433410645
# nan 0.026234298944473267
# nan 0.02849753201007843
# nan 0.02666504494845867
# nan 0.03596483916044235
# nan nan
# nan 0.025319894775748253
# nan 0.03363077715039253
# nan 0.02979930490255356
# nan 0.03822862729430199
# nan 0.03649681806564331
# nan 0.01985427737236023
# nan 0.04228461906313896
# nan nan
# nan 0.024844544008374214
# nan 0.03008623979985714
# nan 0.030144251883029938
# nan 0.03227057307958603
# nan 0.029472041875123978
# nan 0.0334525890648365
# nan 0.025019485503435135
# nan nan
# nan nan
# nan nan
# nan 0.02926383726298809
# nan 0.028949303552508354
# nan 0.030326474457979202
# nan 0.025111179798841476
# nan 0.023541200906038284
# nan 0.03462329879403114
# nan 0.0366465300321579
# nan 0.04122921824455261
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan

# %%
artifact = run.use_artifact("bike-dataset:latest")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      26 except requests.HTTPError as error:
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/runs.py:858, in Run.use_artifact(self, artifact, use_as)
#     857 else:
# --> 858     raise ValueError("You must pass a wandb.Api().artifact() to use_artifact")
#
# ValueError: You must pass a wandb.Api().artifact() to use_artifact
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 artifact = run.use_artifact("bike-dataset:latest")
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/normalize.py:71, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      69     raise
#      70 else:
# ---> 71     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/normalize.py:25, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      23 message = "Whoa, you found a bug."
#      24 try:
# ---> 25     return func(*args, **kwargs)
#      26 except requests.HTTPError as error:
#      27     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/symmetry/lib/python3.11/site-packages/wandb/apis/public/runs.py:858, in Run.use_artifact(self, artifact, use_as)
#     853     raise ValueError(
#     854         "Only existing artifacts are accepted by this api. "
#     855         "Manually create one with `wandb artifact put`"
#     856     )
#     857 else:
# --> 858     raise ValueError("You must pass a wandb.Api().artifact() to use_artifact")
#
# CommError: You must pass a wandb.Api().artifact() to use_artifact
