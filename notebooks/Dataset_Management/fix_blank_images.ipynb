# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../src/utils/')
from utils import detect_blank_images

# Usage
h5_file = '../../datasets/imagenet_v5_rot_10m.h5'
blank_image_index = detect_blank_images(h5_file, dataset_name='data', group_name='train')
# Out:
#   7%|▋         | 698969/10710034 [01:08<17:30, 9530.48it/s]
