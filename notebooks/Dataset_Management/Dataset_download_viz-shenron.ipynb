# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import torch
import glob
import sys
sys.path.append('../../src/utils')
from utils import datafed_download, datafed_upload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
datafed_upload('../../../imagenet_bg_atom_v5_1m-11.h5', 'c/517742443')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datafed_upload('../../../imagenet_bg_atom_v5_1m-11.h5', 'c/517742443')
#
# File ~/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning/notebooks/Dataset_Management/../../src/utils/utils.py:396, in datafed_upload(file_path, parent_id, metadata, wait)
#     394 dc_resp = df_api.dataCreate(file_name, metadata=json.dumps(metadata), parent_id=parent_id)
#     395 rec_id = dc_resp[0].data[0].id
# --> 396 put_resp = df_api.dataPut(rec_id, file_path, wait=wait)
#     397 print(put_resp)
#
# File ~/anaconda3/envs/symmetry/lib/python3.10/site-packages/datafed/CommandLib.py:862, in API.dataPut(self, data_id, path, encrypt, wait, timeout_sec, extension, context)
#     859 elapsed = 0
#     861 while True:
# --> 862     time.sleep(4)
#     863     elapsed = elapsed + 4
# ...
