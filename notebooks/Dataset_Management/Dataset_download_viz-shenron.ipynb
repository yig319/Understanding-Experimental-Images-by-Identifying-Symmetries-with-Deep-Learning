# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import torch
import glob
import sys
sys.path.append('../../src/utils')
from utils import datafed_download, datafed_upload

# %%
datafed_download('d/518810265', file_path='../../datasets/', wait=True)
datafed_download('d/518979321', file_path='../../datasets/', wait=True)
# Out:
# (task {
#   id: "task/523923999"
#   type: TT_DATA_GET
#   status: TS_SUCCEEDED
#   client: "u/yig319"
#   step: 2
#   steps: 3
#   msg: "Finished"
#   ct: 1717185718
#   ut: 1717185831
#   source: "d/518810265"
#   dest: "465e94c2-92ce-11ee-8c81-fd88ce9321ad/home/jca92/yichen/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning/datasets"
# }
# , 'TaskDataReply')
# (task {
#   id: "task/523924726"
#   type: TT_DATA_GET
#   status: TS_SUCCEEDED
#   client: "u/yig319"
#   step: 2
#   steps: 3
#   msg: "Finished"
#   ct: 1717185835
#   ut: 1717185917
#   source: "d/518979321"
#   dest: "465e94c2-92ce-11ee-8c81-fd88ce9321ad/home/jca92/yichen/Understanding-Experimental-Images-by-Identifying-Symmetries-with-Deep-Learning/datasets"
# }
# , 'TaskDataReply')

# %%
datafed_upload('~/Wallpaper_Group_Symmetry_Dataset/example_images/imagenet_p4_example_steps.svg',
               'c/506994388')
