# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import h5py

import torch
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from trainer_ddp import main

# %%
world_size = torch.cuda.device_count()
total_epochs = 3
batch_size = 128
lr = 1e-3 
tracking = False
mp.spawn(main, args=(world_size, total_epochs, batch_size, lr, tracking), nprocs=world_size)
# Out:
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1938ad8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 707456) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f82b7adcca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 708062) is killed by signal: Aborted.
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbb980d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 707887) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f75afa00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 708238) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbcc50dcca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 709318) is killed by signal: Aborted.
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f25f06d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 709619) is killed by signal: Aborted.
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb52f4d8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 709818) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7faa8a6d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 711000) is killed by signal: Aborted.
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f03bd4d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 710008) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
#   0%|          | 0/79 [00:00<?, ?it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd721a00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 710016) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:18<00:00,  4.27it/s]
#  81%|████████  | 64/79 [00:16<00:02,  5.11it/s]
# Epoch 0: train Loss: 0.3059, train Accuracy: 0.64%
# 100%|██████████| 79/79 [00:18<00:00,  4.28it/s]
# 100%|██████████| 79/79 [00:18<00:00,  4.33it/s]
# 100%|██████████| 79/79 [00:18<00:00,  4.27it/s]
#  90%|████████▉ | 71/79 [00:17<00:01,  5.02it/s]
# Epoch 0: train Loss: 0.3054, train Accuracy: 0.59%
# Epoch 0: train Loss: 0.3054, train Accuracy: 0.60%
# Epoch 0: train Loss: 0.3085, train Accuracy: 0.59%
# 100%|██████████| 79/79 [00:17<00:00,  5.99it/s]terminate called without an active exception
#  95%|█████████▍| 75/79 [00:17<00:00,  5.19it/s]terminate called without an active exception
#  91%|█████████ | 72/79 [00:18<00:01,  4.85it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1938ad8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 720036) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:18<00:00,  4.33it/s]
#  97%|█████████▋| 77/79 [00:18<00:00,  5.06it/s]
# Epoch 0: train Loss: 0.3070, train Accuracy: 0.63%
#  95%|█████████▍| 75/79 [00:19<00:00,  4.95it/s]terminate called without an active exception
#  97%|█████████▋| 77/79 [00:19<00:00,  4.90it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# 100%|██████████| 79/79 [00:19<00:00,  5.80it/s]terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f75afa00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 720320) is killed by signal: Aborted.
#  96%|█████████▌| 76/79 [00:19<00:00,  4.97it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#  99%|█████████▊| 78/79 [00:19<00:00,  4.89it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f82b7adcca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 720304) is killed by signal: Aborted.
# terminate called without an active exception
#   0%|          | 0/79 [00:00<?, ?it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbb980d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 720322) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:19<00:00,  4.09it/s]
#  97%|█████████▋| 77/79 [00:19<00:00,  4.96it/s]
# Epoch 0: train Loss: 0.3053, train Accuracy: 0.60%
# Epoch 0: train Loss: 0.3051, train Accuracy: 0.63%
# 100%|██████████| 79/79 [00:19<00:00,  4.07it/s]
# 100%|██████████| 79/79 [00:19<00:00,  3.97it/s]
# Epoch 0: train Loss: 0.3058, train Accuracy: 0.61%
# 100%|██████████| 79/79 [00:20<00:00,  3.88it/s]
#   1%|▏         | 1/79 [00:02<02:38,  2.03s/it]
# Epoch 0: train Loss: 0.3053, train Accuracy: 0.60%
# 100%|██████████| 79/79 [00:20<00:00,  3.84it/s]
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd721a00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 721411) is killed by signal: Aborted.
#   4%|▍         | 3/79 [00:02<00:46,  1.64it/s]
# Epoch 0: train Loss: 0.3074, train Accuracy: 0.59%
#   9%|▉         | 7/79 [00:03<00:19,  3.72it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#   1%|▏         | 1/79 [00:02<02:50,  2.18s/it]terminate called without an active exception
#   1%|▏         | 1/79 [00:02<02:47,  2.15s/it]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7faa8a6d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 722764) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#   3%|▎         | 2/79 [00:02<01:17,  1.01s/it]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f03bd4d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 722775) is killed by signal: Aborted.
#  11%|█▏        | 9/79 [00:03<00:16,  4.33it/s]terminate called without an active exception
# terminate called without an active exception
#   4%|▍         | 3/79 [00:02<00:51,  1.48it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f25f06d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 723485) is killed by signal: Aborted.
#   6%|▋         | 5/79 [00:02<00:26,  2.75it/s]]terminate called without an active exception
#  15%|█▌        | 12/79 [00:04<00:14,  4.65it/s]terminate called without an active exception
#   6%|▋         | 5/79 [00:02<00:28,  2.63it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb52f4d8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 724832) is killed by signal: Aborted.
#   8%|▊         | 6/79 [00:03<00:23,  3.13it/s]terminate called without an active exception
# 100%|██████████| 79/79 [00:17<00:00,  4.42it/s]
#  75%|███████▍  | 59/79 [00:12<00:03,  5.19it/s]
# Epoch 1: train Loss: 0.2948, train Accuracy: 0.60%
# 100%|██████████| 79/79 [00:17<00:00,  4.44it/s]
# 100%|██████████| 79/79 [00:18<00:00,  4.38it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.43it/s]
#  87%|████████▋ | 69/79 [00:15<00:01,  5.12it/s]
# Epoch 1: train Loss: 0.2951, train Accuracy: 0.60%
# Epoch 1: train Loss: 0.2950, train Accuracy: 0.61%
# Epoch 1: train Loss: 0.2947, train Accuracy: 0.60%
#  95%|█████████▍| 75/79 [00:16<00:00,  5.05it/s]terminate called without an active exception
#  99%|█████████▊| 78/79 [00:17<00:00,  4.99it/s]terminate called without an active exception
#  91%|█████████ | 72/79 [00:15<00:01,  5.14it/s]terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1938ad8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 730932) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:17<00:00,  4.43it/s]
#  91%|█████████ | 72/79 [00:15<00:01,  5.09it/s]
# Epoch 1: train Loss: 0.2957, train Accuracy: 0.62%
#  94%|█████████▎| 74/79 [00:15<00:00,  5.07it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#  99%|█████████▊| 78/79 [00:17<00:00,  4.89it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#  99%|█████████▊| 78/79 [00:16<00:00,  5.15it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f82b7adcca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
# terminate called without an active exception
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 731202) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:17<00:00,  4.49it/s]
# terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbb980d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 731223) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:17<00:00,  4.51it/s]
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f75afa00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 731212) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 1: train Loss: 0.2944, train Accuracy: 0.54%
# Epoch 1: train Loss: 0.2945, train Accuracy: 0.60%
# 100%|██████████| 79/79 [00:17<00:00,  4.54it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.43it/s]
# Epoch 1: train Loss: 0.2945, train Accuracy: 0.56%
# Epoch 1: train Loss: 0.2949, train Accuracy: 0.61%
#   3%|▎         | 2/79 [00:02<01:12,  1.06it/s]terminate called without an active exception
#   4%|▍         | 3/79 [00:02<00:45,  1.66it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# 100%|██████████| 79/79 [00:17<00:00,  4.54it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd721a00ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 732563) is killed by signal: Aborted.
#   5%|▌         | 4/79 [00:02<00:33,  2.27it/s]
# Epoch 1: train Loss: 0.2942, train Accuracy: 0.62%
#   8%|▊         | 6/79 [00:02<00:21,  3.38it/s]terminate called without an active exception
#   9%|▉         | 7/79 [00:03<00:19,  3.71it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#   1%|▏         | 1/79 [00:02<02:42,  2.08s/it]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f03bd4d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 733657) is killed by signal: Aborted.
#   0%|          | 0/79 [00:00<?, ?it/s]terminate called without an active exception
# terminate called without an active exception
#   1%|▏         | 1/79 [00:02<02:44,  2.11s/it]terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7faa8a6d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 733623) is killed by signal: Aborted.
#  13%|█▎        | 10/79 [00:03<00:15,  4.58it/s]terminate called without an active exception
#   5%|▌         | 4/79 [00:02<00:33,  2.22it/s]terminate called without an active exception
#   4%|▍         | 3/79 [00:02<00:48,  1.58it/s]terminate called without an active exception
# terminate called without an active exception
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fb52f4d8ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 735228) is killed by signal: Aborted.
#   5%|▌         | 4/79 [00:02<00:34,  2.16it/s]terminate called without an active exception
#   0%|          | 0/79 [00:00<?, ?it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f25f06d4ca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 735240) is killed by signal: Aborted.
#   8%|▊         | 6/79 [00:03<00:22,  3.27it/s]terminate called without an active exception
# terminate called without an active exception
# terminate called without an active exception
#   1%|▏         | 1/79 [00:02<02:38,  2.04s/it]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbcc50dcca0>
# Traceback (most recent call last):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/yichen/anaconda3/envs/symmetry/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 736029) is killed by signal: Aborted.
# 100%|██████████| 79/79 [00:17<00:00,  4.58it/s]
#  86%|████████▌ | 68/79 [00:14<00:02,  5.34it/s]
# Epoch 2: train Loss: 0.2926, train Accuracy: 0.57%
# 100%|██████████| 79/79 [00:17<00:00,  4.54it/s]
#  90%|████████▉ | 71/79 [00:15<00:01,  5.32it/s]
# Epoch 2: train Loss: 0.2916, train Accuracy: 0.59%
# Epoch 2: train Loss: 0.2919, train Accuracy: 0.63%
# 100%|██████████| 79/79 [00:17<00:00,  4.50it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.46it/s]
#  94%|█████████▎| 74/79 [00:15<00:00,  5.24it/s]
# Epoch 2: train Loss: 0.2927, train Accuracy: 0.61%
# 100%|██████████| 79/79 [00:17<00:00,  4.61it/s]
#  94%|█████████▎| 74/79 [00:15<00:00,  5.20it/s]
# Epoch 2: train Loss: 0.2912, train Accuracy: 0.62%
# 100%|██████████| 79/79 [00:17<00:00,  4.62it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.63it/s]
#  99%|█████████▊| 78/79 [00:16<00:00,  5.20it/s]
# Epoch 2: train Loss: 0.2920, train Accuracy: 0.59%
# Epoch 2: train Loss: 0.2911, train Accuracy: 0.62%
# 100%|██████████| 79/79 [00:16<00:00,  4.66it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.64it/s]
#  99%|█████████▊| 78/79 [00:16<00:00,  5.25it/s]
# Epoch 2: train Loss: 0.2920, train Accuracy: 0.60%
# Epoch 2: train Loss: 0.2924, train Accuracy: 0.55%
# 100%|██████████| 79/79 [00:16<00:00,  4.67it/s]
# Epoch 2: train Loss: 0.2909, train Accuracy: 0.65%
