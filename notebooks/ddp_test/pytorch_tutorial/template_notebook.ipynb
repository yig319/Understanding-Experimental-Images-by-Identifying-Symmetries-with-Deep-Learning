# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import h5py

import torch
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from multigpu import main

# %%
os.environ['CUDA_VISIBLE_DEVICES']='0,1'

world_size = torch.cuda.device_count()
save_every = 5
total_epochs = 20
batch_size = 128
mp.spawn(main, args=(world_size, save_every, total_epochs, batch_size), nprocs=world_size)
# Out:
# [GPU1] Epoch 0 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 0 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 1 | Batchsize: 128 | Steps: 8
# Epoch 0 | Training checkpoint saved at checkpoint.pt
# [GPU0] Epoch 1 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 2 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 2 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 3 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 3 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 4 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 4 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 5 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 5 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 6 | Batchsize: 128 | Steps: 8
# Epoch 5 | Training checkpoint saved at checkpoint.pt
# [GPU0] Epoch 6 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 7 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 7 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 8 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 8 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 9 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 9 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 10 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 10 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 11 | Batchsize: 128 | Steps: 8
# Epoch 10 | Training checkpoint saved at checkpoint.pt
# [GPU0] Epoch 11 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 12 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 12 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 13 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 13 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 14 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 14 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 15 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 15 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 16 | Batchsize: 128 | Steps: 8
# Epoch 15 | Training checkpoint saved at checkpoint.pt
# [GPU0] Epoch 16 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 17 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 17 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 18 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 18 | Batchsize: 128 | Steps: 8
# [GPU1] Epoch 19 | Batchsize: 128 | Steps: 8
# [GPU0] Epoch 19 | Batchsize: 128 | Steps: 8
