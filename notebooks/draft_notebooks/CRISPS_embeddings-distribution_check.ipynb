# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import h5py
from matplotlib import pyplot as plt
import pandas as pd
from dl_utils.utils.utils import viz_h5_structure

# %%
# load image from the dataset
images, titles = [], []
with h5py.File("../../datasets/imagenet_v5_rot_10k_fix_vector_a100_0_xcit_embeddings.h5", 'r') as f:
    viz_h5_structure(f)
    embeddings = np.array(f['embeddings'][:])  # shape: [N, D]
# Out:
# 'Dataset': embeddings; Shape: (10013, 384); dtype: float32

# %%
pd = pd.DataFrame(embeddings)
pd
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.000800  0.000920  0.003557  0.000473 -0.000358 -0.809480  0.000771
# 1      0.001472  0.001056  0.000155  0.001165 -0.000834 -0.730401  0.000626
# 2      0.001578  0.001083  0.001720  0.001221 -0.001001 -0.503425  0.000596
# 3      0.001153  0.000980  0.000476  0.000740 -0.000439  0.072540  0.000690
# 4      0.000502  0.000854  0.001998  0.000119  0.000116 -0.635773  0.000809
# ...         ...       ...       ...       ...       ...       ...       ...
# 10008  0.001349  0.001028 -0.001427  0.000921 -0.000681  0.022469  0.000638
# 10009  0.002215  0.001188 -0.002043  0.001705 -0.001566 -0.499500  0.000498
# 10010  0.000974  0.000961  0.002931  0.000688 -0.000393 -0.364172  0.000706
# 10011  0.000918  0.000942  0.002633  0.000576 -0.000447 -0.781160  0.000759
# 10012  0.001538  0.001073  0.001899  0.001175 -0.000969 -0.539544  0.000605
#
# ...

# %%
pd.describe()
# Out:
#                 0             1             2             3             4    \
# count  10013.000000  10013.000000  10013.000000  10013.000000  10013.000000
# mean       0.001416      0.001042      0.000643      0.001023     -0.000811
# std        0.000544      0.000108      0.001702      0.000502      0.000551
# min        0.000298      0.000817     -0.006044     -0.000062     -0.001908
# 25%        0.000995      0.000958     -0.000336      0.000661     -0.001237
# 50%        0.001477      0.001057      0.000861      0.001133     -0.000861
# 75%        0.001856      0.001128      0.001799      0.001408     -0.000412
# max        0.002419      0.001247      0.005062      0.001959      0.000394
#
#                 5             6             7             8             9    \
# count  10013.000000  10013.000000  10013.000000  10013.000000  10013.000000
# mean      -0.428020      0.000640     -0.001245      0.000952      0.000843
# ...

# %%
h = plt.hist(embeddings[:, 0], bins=100)

# %%
h = plt.hist(embeddings[0, :], bins=100)

# %%
# load image from the dataset
images, titles = [], []
with h5py.File("../../datasets/imagenet_v5_rot_10k_fix_vector_a100_0_ResNet50_embeddings.h5", 'r') as f:
    viz_h5_structure(f)
    embeddings = np.array(f['embeddings'][:])  # shape: [N, D]
# Out:
# 'Dataset': embeddings; Shape: (10013, 2048); dtype: float32

# %%
h = plt.hist(embeddings[0, :], bins=100)

# %%
h = plt.hist(np.array(embeddings), bins=100)

# %%
pd = pd.DataFrame(embeddings)
pd
# Out:
#            0         1         2         3         4         5         6     \
# 0      0.533669  0.900104  1.463838  0.310423  0.029336  0.021237  0.137296
# 1      0.053738  0.138879  0.391567  2.632040  0.036943  0.056478  0.995317
# 2      0.002794  0.060561  0.000000  0.110402  0.041254  0.000000  0.798913
# 3      0.028986  0.868181  0.022506  0.207384  0.038562  0.652232  0.314686
# 4      0.007403  1.217422  0.537331  0.494938  0.038036  0.197646  0.117979
# ...         ...       ...       ...       ...       ...       ...       ...
# 10008  0.001051  0.000000  0.559737  0.042774  0.050459  0.010993  0.170092
# 10009  0.131854  0.097665  2.566725  0.013198  0.058118  0.000000  0.000000
# 10010  0.024248  0.070349  0.160698  0.199003  0.111580  0.001288  0.172474
# 10011  0.471256  1.070802  0.982394  0.590633  0.034362  0.000411  0.093541
# 10012  0.000000  0.272586  0.003947  0.073171  0.028617  0.017578  0.874431
#
# ...

# %%
pd.describe()
# Out:
#                0             1             2             3             4     \
# count  10013.000000  10013.000000  10013.000000  10013.000000  10013.000000
# mean       0.097934      0.304961      0.485660      0.532313      0.041686
# std        0.153754      0.378357      0.754859      0.935280      0.021204
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.001877      0.030193      0.033457      0.026840      0.028332
# 50%        0.022404      0.100601      0.163120      0.152281      0.038295
# 75%        0.102940      0.532804      0.698876      0.452258      0.050123
# max        0.802967      1.750338      6.549328      5.894793      0.275314
#
#                5             6             7             8             9     \
# count  10013.000000  10013.000000  10013.000000  10013.000000  10013.000000
# mean       0.115259      0.390339      0.155084      0.192151      0.395519
# ...

# %%
h = plt.hist(embeddings[:, 800], bins=100)

# %%
h = plt.hist(embeddings.flatten(), bins=20)
